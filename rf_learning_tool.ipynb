# %% [markdown]
# <a href="https://colab.research.google.com/github/Sneha123-zudo/Machine-Learning---Learning/blob/main/rf_learning_tool.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
from sklearn.datasets import make_classification

# %%
X,y = make_classification(n_features=5, n_redundant=0, n_informative=5, n_clusters_per_class=1)

# %%
df = pd.DataFrame(X, columns=['col1','col2','col3','col4','col5'])
df['target'] = y
print(df.shape)
df.head()
# Out:
# (100, 6)
#        col1      col2      col3      col4      col5  target
# 0  3.488692 -0.976057 -1.019595 -1.172015  0.393809       0
# 1 -1.786253 -1.454896 -2.126149  2.071268 -1.029567       1
# 2 -3.388126 -2.407434 -0.895399  1.042578 -0.299063       1
# 3  1.037722 -0.832360  2.432306 -3.992448 -1.993501       0
# 4  2.155143  1.005198  0.007824 -1.391806 -0.933500       0

# %%
#function for sample rows - it will generate the data randomly
def sample_rows(df,percent):
  return df.sample(int(percent*df.shape[0]), replace=True)

# %%
#function for feature sampling
def sample_features(df, percent):
  cols = random.sample(df.columns.tolist(), int(percent*df.shape[1]))
  return df[cols]

# %%
def combined_sampling(df, row_percent, col_percent):
  new_df = sample_rows(df,row_percent)
  return sample_features(new_df,col_percent)

# %%
df1 = sample_rows(df, 0.2)

# %%
df2 = sample_rows(df,0.2)

# %%
df3 = sample_rows(df,0.2)

# %%
df1.shape, df2.shape, df3.shape
# Out:
# ((20, 6), (20, 6), (20, 6))

# %%
from sklearn.tree import DecisionTreeClassifier
clf1 = DecisionTreeClassifier()
clf2 = DecisionTreeClassifier()
clf3 = DecisionTreeClassifier()

# %%
clf1.fit(df1.iloc[:,0:5], df1.iloc[:,-1])
clf2.fit(df2.iloc[:,0:5], df2.iloc[:,-1])
clf3.fit(df3.iloc[:,0:5], df3.iloc[:,-1])
# Out:
# DecisionTreeClassifier()

# %%
from sklearn.tree import plot_tree

# %%
plot_tree(clf1)
# Out:
# [Text(0.6, 0.875, 'x[3] <= 0.705\ngini = 0.495\nsamples = 20\nvalue = [11, 9]'),
#  Text(0.4, 0.625, 'x[3] <= -2.592\ngini = 0.26\nsamples = 13\nvalue = [11, 2]'),
#  Text(0.5, 0.75, 'True  '),
#  Text(0.2, 0.375, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.6, 0.375, 'x[1] <= 0.703\ngini = 0.153\nsamples = 12\nvalue = [11, 1]'),
#  Text(0.4, 0.125, 'gini = 0.0\nsamples = 11\nvalue = [11, 0]'),
#  Text(0.8, 0.125, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.8, 0.625, 'gini = 0.0\nsamples = 7\nvalue = [0, 7]'),
#  Text(0.7, 0.75, '  False')]

# %%
plot_tree(clf2)
# Out:
# [Text(0.42857142857142855, 0.9166666666666666, 'x[3] <= 1.344\ngini = 0.5\nsamples = 20\nvalue = [10, 10]'),
#  Text(0.2857142857142857, 0.75, 'x[4] <= -2.182\ngini = 0.444\nsamples = 15\nvalue = [10, 5]'),
#  Text(0.3571428571428571, 0.8333333333333333, 'True  '),
#  Text(0.14285714285714285, 0.5833333333333334, 'gini = 0.0\nsamples = 6\nvalue = [6, 0]'),
#  Text(0.42857142857142855, 0.5833333333333334, 'x[0] <= -0.396\ngini = 0.494\nsamples = 9\nvalue = [4, 5]'),
#  Text(0.2857142857142857, 0.4166666666666667, 'gini = 0.0\nsamples = 3\nvalue = [0, 3]'),
#  Text(0.5714285714285714, 0.4166666666666667, 'x[0] <= -0.111\ngini = 0.444\nsamples = 6\nvalue = [4, 2]'),
#  Text(0.42857142857142855, 0.25, 'gini = 0.0\nsamples = 3\nvalue = [3, 0]'),
#  Text(0.7142857142857143, 0.25, 'x[0] <= 1.231\ngini = 0.444\nsamples = 3\nvalue = [1, 2]'),
#  Text(0.5714285714285714, 0.08333333333333333, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
# ...

# %%
plot_tree(clf3)
# Out:
# [Text(0.5, 0.8333333333333334, 'x[3] <= -0.263\ngini = 0.495\nsamples = 20\nvalue = [11, 9]'),
#  Text(0.25, 0.5, 'x[0] <= -1.213\ngini = 0.165\nsamples = 11\nvalue = [10, 1]'),
#  Text(0.375, 0.6666666666666667, 'True  '),
#  Text(0.125, 0.16666666666666666, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.375, 0.16666666666666666, 'gini = 0.0\nsamples = 10\nvalue = [10, 0]'),
#  Text(0.75, 0.5, 'x[4] <= 1.047\ngini = 0.198\nsamples = 9\nvalue = [1, 8]'),
#  Text(0.625, 0.6666666666666667, '  False'),
#  Text(0.625, 0.16666666666666666, 'gini = 0.0\nsamples = 8\nvalue = [0, 8]'),
#  Text(0.875, 0.16666666666666666, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]')]

# %%
clf1.predict(np.array([-1.042498, -0.064323, 0, 0, 0]).reshape(1,5))
# Out:
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
#   warnings.warn(
# array([0])

# %%
clf2.predict(np.array([-1.042498, -0.064323, 0, 0, 0]).reshape(1,5))
# Out:
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
#   warnings.warn(
# array([1])

# %%
clf3.predict(np.array([-1.042498, -0.064323, 0, 0, 0]).reshape(1,5))
# Out:
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
#   warnings.warn(
# array([1])
